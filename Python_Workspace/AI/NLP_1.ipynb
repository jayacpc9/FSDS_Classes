# %% [markdown]
# # To download all the supporting packages of nltk
# # DAY 1 : 07302026 : NLP

# %%
import os
import nltk
# nltk.download() # download only once

# %%
nltk.__version__
# Out:
# '3.9.2'

# %% [markdown]
# # DAY 2 : 07312026 : NLP

# %%
AI = '''Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of
humans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and
problem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.
It is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe
AI could solve major challenges and crisis situations.'''

# %%
print(AI)
# Out:
# Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of
# humans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and
# problem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.
# It is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe
# AI could solve major challenges and crisis situations.

# %%
type(AI)
# Out:
# str

# %%
from nltk.tokenize import word_tokenize
AI_tokens = word_tokenize(AI)
print(AI_tokens)
print("Token length = ",len(AI_tokens))
# Out:
# ['Artificial', 'Intelligence', 'refers', 'to', 'the', 'intelligence', 'of', 'machines', '.', 'This', 'is', 'in', 'contrast', 'to', 'the', 'natural', 'intelligence', 'of', 'humans', 'and', 'animals', '.', 'With', 'Artificial', 'Intelligence', ',', 'machines', 'perform', 'functions', 'such', 'as', 'learning', ',', 'planning', ',', 'reasoning', 'and', 'problem-solving', '.', 'Most', 'noteworthy', ',', 'Artificial', 'Intelligence', 'is', 'the', 'simulation', 'of', 'human', 'intelligence', 'by', 'machines', '.', 'It', 'is', 'probably', 'the', 'fastest-growing', 'development', 'in', 'the', 'World', 'of', 'technology', 'and', 'innovation', '.', 'Furthermore', ',', 'many', 'experts', 'believe', 'AI', 'could', 'solve', 'major', 'challenges', 'and', 'crisis', 'situations', '.']
# Token length =  81

# %%
from nltk.tokenize import sent_tokenize
AI_sent = sent_tokenize(AI)
AI_sent
# Out:
# ['Artificial Intelligence refers to the intelligence of machines.',
#  'This is in contrast to the natural intelligence of\nhumans and animals.',
#  'With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving.',
#  'Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.',
#  'It is probably the fastest-growing development in the World of technology and innovation.',
#  'Furthermore, many experts believe\nAI could solve major challenges and crisis situations.']

# %%
print("Length of Tokens sent = ",len(AI_sent))
# Out:
# Length of Tokens sent =  6

# %%
AI
# Out:
# 'Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of\nhumans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.\nIt is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe\nAI could solve major challenges and crisis situations.'

# %%
from nltk.tokenize import blankline_tokenize
AI_blank = blankline_tokenize(AI)
print(AI_blank)
print("Length of Blank Line Tokenize = ",len(AI_blank))
# Out:
# ['Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of\nhumans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.\nIt is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe\nAI could solve major challenges and crisis situations.']
# Length of Blank Line Tokenize =  1

# %% [markdown]
# # WhitespaceTokenizer : eliminates all puncutations like , . whitespace etc

# %%
from nltk.tokenize import WhitespaceTokenizer
AI_white = WhitespaceTokenizer().tokenize(AI)
print(AI_white)
print("Length of Whitespace Tokenizer = ",len(AI_white))
# Out:
# ['Artificial', 'Intelligence', 'refers', 'to', 'the', 'intelligence', 'of', 'machines.', 'This', 'is', 'in', 'contrast', 'to', 'the', 'natural', 'intelligence', 'of', 'humans', 'and', 'animals.', 'With', 'Artificial', 'Intelligence,', 'machines', 'perform', 'functions', 'such', 'as', 'learning,', 'planning,', 'reasoning', 'and', 'problem-solving.', 'Most', 'noteworthy,', 'Artificial', 'Intelligence', 'is', 'the', 'simulation', 'of', 'human', 'intelligence', 'by', 'machines.', 'It', 'is', 'probably', 'the', 'fastest-growing', 'development', 'in', 'the', 'World', 'of', 'technology', 'and', 'innovation.', 'Furthermore,', 'many', 'experts', 'believe', 'AI', 'could', 'solve', 'major', 'challenges', 'and', 'crisis', 'situations.']
# Length of Whitespace Tokenizer =  70

# %%
s ="Good apple costs $3.88 in hyderabad. Please buy two of them. Thanks."
s
# Out:
# 'Good apple costs $3.88 in hyderabad. Please buy two of them. Thanks.'

# %% [markdown]
# # wordpunct_tokenize : if token has numbers then we use it

# %%
from nltk.tokenize import wordpunct_tokenize
word_punct_tokens = wordpunct_tokenize(s)
print("Length of word_punct_tokens = ",len(word_punct_tokens))
word_punct_tokens
# Out:
# Length of word_punct_tokens =  18
# ['Good',
#  'apple',
#  'costs',
#  '$',
#  '3',
#  '.',
#  '88',
#  'in',
#  'hyderabad',
#  '.',
#  'Please',
#  'buy',
#  'two',
#  'of',
#  'them',
#  '.',
#  'Thanks',
#  '.']

# %%
from nltk.tokenize import WhitespaceTokenizer
whitespace_tokens=WhitespaceTokenizer().tokenize(s)

print("Length of whitespace_tokens = ",len(whitespace_tokens))
whitespace_tokens
# Out:
# Length of whitespace_tokens =  12
# ['Good',
#  'apple',
#  'costs',
#  '$3.88',
#  'in',
#  'hyderabad.',
#  'Please',
#  'buy',
#  'two',
#  'of',
#  'them.',
#  'Thanks.']

# %%
AI
# Out:
# 'Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of\nhumans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.\nIt is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe\nAI could solve major challenges and crisis situations.'

# %%
from nltk.tokenize import wordpunct_tokenize
word_punct_tokens_AI = wordpunct_tokenize(AI)
print("Length of word_punct_tokens_AI = ",len(word_punct_tokens_AI))
print(word_punct_tokens_AI)
# Out:
# Length of word_punct_tokens_AI =  85
# ['Artificial', 'Intelligence', 'refers', 'to', 'the', 'intelligence', 'of', 'machines', '.', 'This', 'is', 'in', 'contrast', 'to', 'the', 'natural', 'intelligence', 'of', 'humans', 'and', 'animals', '.', 'With', 'Artificial', 'Intelligence', ',', 'machines', 'perform', 'functions', 'such', 'as', 'learning', ',', 'planning', ',', 'reasoning', 'and', 'problem', '-', 'solving', '.', 'Most', 'noteworthy', ',', 'Artificial', 'Intelligence', 'is', 'the', 'simulation', 'of', 'human', 'intelligence', 'by', 'machines', '.', 'It', 'is', 'probably', 'the', 'fastest', '-', 'growing', 'development', 'in', 'the', 'World', 'of', 'technology', 'and', 'innovation', '.', 'Furthermore', ',', 'many', 'experts', 'believe', 'AI', 'could', 'solve', 'major', 'challenges', 'and', 'crisis', 'situations', '.']

# %%
# import nltk

# NLTK_DATA_HOME ="/Users/chandra/nltk_data"
# NLTK_DATA_DOWNLOAD="/Users/chandra/nltk_data/downloads"

# nltk.data.path.append(NLTK_DATA_HOME)
# nltk.download('punkt', download_dir=NLTK_DATA_DOWNLOAD)

# %% [markdown]
# # Types of Tokens
# #### Bigrams: tokens with 2 words
# #### Trigrams : tokens with 3 words
# #### Ngrams : tokens of any number of words

# %%
from nltk.util import bigrams,trigrams, ngrams
string = "generative ai & agentic ai is automate the industry & more focus on every domain"
quotes_tokens = nltk.word_tokenize(string)

print("Length of quotes_tokens = ",len(quotes_tokens))
print(quotes_tokens)
# Out:
# Length of quotes_tokens =  15
# ['generative', 'ai', '&', 'agentic', 'ai', 'is', 'automate', 'the', 'industry', '&', 'more', 'focus', 'on', 'every', 'domain']

# %%
quotes_bigram = list(nltk.bigrams(quotes_tokens))

print("Length of quotes_bigram =",len(quotes_bigram))
quotes_bigram
# Out:
# Length of quotes_bigram = 14
# [('generative', 'ai'),
#  ('ai', '&'),
#  ('&', 'agentic'),
#  ('agentic', 'ai'),
#  ('ai', 'is'),
#  ('is', 'automate'),
#  ('automate', 'the'),
#  ('the', 'industry'),
#  ('industry', '&'),
#  ('&', 'more'),
#  ('more', 'focus'),
#  ('focus', 'on'),
#  ('on', 'every'),
#  ('every', 'domain')]

# %%
quotes_trigram = list(nltk.trigrams(quotes_tokens))
print("Length of quotes_trigram =",len(quotes_trigram))
quotes_trigram
# Out:
# Length of quotes_trigram = 13
# [('generative', 'ai', '&'),
#  ('ai', '&', 'agentic'),
#  ('&', 'agentic', 'ai'),
#  ('agentic', 'ai', 'is'),
#  ('ai', 'is', 'automate'),
#  ('is', 'automate', 'the'),
#  ('automate', 'the', 'industry'),
#  ('the', 'industry', '&'),
#  ('industry', '&', 'more'),
#  ('&', 'more', 'focus'),
#  ('more', 'focus', 'on'),
#  ('focus', 'on', 'every'),
#  ('on', 'every', 'domain')]

# %%
quotes_ngrams = list(nltk.ngrams(quotes_tokens,n=5))
print("Length of quotes_ngrams =",len(quotes_ngrams))
quotes_ngrams
# Out:
# Length of quotes_ngrams = 11
# [('generative', 'ai', '&', 'agentic', 'ai'),
#  ('ai', '&', 'agentic', 'ai', 'is'),
#  ('&', 'agentic', 'ai', 'is', 'automate'),
#  ('agentic', 'ai', 'is', 'automate', 'the'),
#  ('ai', 'is', 'automate', 'the', 'industry'),
#  ('is', 'automate', 'the', 'industry', '&'),
#  ('automate', 'the', 'industry', '&', 'more'),
#  ('the', 'industry', '&', 'more', 'focus'),
#  ('industry', '&', 'more', 'focus', 'on'),
#  ('&', 'more', 'focus', 'on', 'every'),
#  ('more', 'focus', 'on', 'every', 'domain')]

# %% [markdown]
# # Stemming and Lematization
# #### Stemming : Root form of a word.  It gives a root word(something like a dictionary)
#
# #### Lematization : Complete word.
# #### for exampe : if token = Playing then
# #### Stemming= play, Lematization = playing

# %%
from nltk.stem import PorterStemmer
pst = PorterStemmer()
pst.stem('affection')
# Out:
# 'affect'

# %%
pst.stem('playing')
# Out:
# 'play'

# %%
pst.stem('maximum')
# Out:
# 'maximum'

# %%
words_to_stem = ['give','giving','given','gave','thinking','loving','maximum','Hello']
for words in words_to_stem:
    print(words+" : "+pst.stem(words))
# Out:
# give : give
# giving : give
# given : given
# gave : gave
# thinking : think
# loving : love
# maximum : maximum
# Hello : hello

# %%
from nltk.stem import LancasterStemmer
lst = LancasterStemmer()

for words in words_to_stem:
    print(words+" : "+lst.stem(words))
# Out:
# give : giv
# giving : giv
# given : giv
# gave : gav
# thinking : think
# loving : lov
# maximum : maxim
# Hello : hello

# %% [markdown]
# # SnowballStemmer : very useful for languages, pass language

# %%
from nltk.stem import SnowballStemmer
def demo_show_ball_stemmer(language):
    sbst = SnowballStemmer(language=language)
    for words in words_to_stem:
        print(words+" : "+sbst.stem(words))
    print("*"*50)

demo_show_ball_stemmer('english')
# Out:
# give : give
# giving : give
# given : given
# gave : gave
# thinking : think
# loving : love
# maximum : maximum
# Hello : hello
# **************************************************

# %%
demo_show_ball_stemmer('german')
demo_show_ball_stemmer('french')
# Out:
# give : giv
# giving : giving
# given : giv
# gave : gav
# thinking : thinking
# loving : loving
# maximum : maximum
# Hello : hello
# **************************************************
# give : giv
# giving : giving
# given : given
# gave : gav
# thinking : thinking
# loving : loving
# maximum : maximum
# Hello : hello
# **************************************************

# %% [markdown]
# # DAY 3 : 08022026 : NLP

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer

word_lem = WordNetLemmatizer()
words_to_stem
# Out:
# ['give', 'giving', 'given', 'gave', 'thinking', 'loving', 'maximum', 'Hello']

# %%
for words in words_to_stem:
    print(words +" : "+word_lem.lemmatize(words))
# Out:
# give : give
# giving : giving
# given : given
# gave : gave
# thinking : thinking
# loving : loving
# maximum : maximum
# Hello : Hello

# %%
from nltk.corpus import stopwords
all_stopwords=stopwords.words('english')
print("English : len(all_stopwords) = ",len(all_stopwords))
print(all_stopwords)
# Out:
# English : len(all_stopwords) =  198
# ...

# %%
def show_all_stop_words(lang):
    from nltk.corpus import stopwords
    all_stopwords=stopwords.words(lang)
    print(lang+" : len(all_stopwords) = ",len(all_stopwords))
    print(all_stopwords)

show_all_stop_words('french')
show_all_stop_words('german')
show_all_stop_words('chinese')
show_all_stop_words('tamil')
show_all_stop_words('bengali')

# show_all_stop_words('hindi')
# show_all_stop_words('telugu')
# show_all_stop_words('odisha')
# Out:
# french : len(all_stopwords) =  157
# ...

# %% [markdown]
# # POS :  Parts of Speech

# %%
sent = 'my name is jaya'
sent_tokens = word_tokenize(sent)
sent_tokens
# Out:
# ['my', 'name', 'is', 'jaya']

# %%
for token in sent_tokens:
    print("nltk.pos_tag : ",nltk.pos_tag([token]))
# Out:
# nltk.pos_tag :  [('my', 'PRP$')]
# nltk.pos_tag :  [('name', 'NN')]
# nltk.pos_tag :  [('is', 'VBZ')]
# nltk.pos_tag :  [('jaya', 'NN')]

# %%
sent2 ='John is eating a delecioius cake'
sent2_tokens = word_tokenize(sent2)

for token in sent2_tokens:
    print("nltk.pos_tag : ",nltk.pos_tag([token]))

# or
print(nltk.pos_tag(sent2_tokens))
# Out:
# nltk.pos_tag :  [('John', 'NNP')]
# nltk.pos_tag :  [('is', 'VBZ')]
# nltk.pos_tag :  [('eating', 'VBG')]
# nltk.pos_tag :  [('a', 'DT')]
# nltk.pos_tag :  [('delecioius', 'NN')]
# nltk.pos_tag :  [('cake', 'NN')]
# [('John', 'NNP'), ('is', 'VBZ'), ('eating', 'VBG'), ('a', 'DT'), ('delecioius', 'NN'), ('cake', 'NN')]

# %% [markdown]
# # Name Entity recognition

# %%
from nltk import word_tokenize 
from nltk.chunk import ne_chunk
ne_sent = 'The us president stays in the Whitehouse'
ne_tokens = word_tokenize(ne_sent)
print(ne_tokens)
ne_tags=nltk.pos_tag(ne_tokens)
ne_tags
# Out:
# ['The', 'us', 'president', 'stays', 'in', 'the', 'Whitehouse']
# [('The', 'DT'),
#  ('us', 'PRP'),
#  ('president', 'NN'),
#  ('stays', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Whitehouse', 'NNP')]

# %%
ne_ner = ne_chunk(ne_tags)
ne_ner
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File /opt/anaconda3/lib/python3.13/site-packages/nltk/tree/tree.py:782, in Tree._repr_svg_(self)
#     781 def _repr_svg_(self):
# --> 782     from svgling import draw_tree
#     784     return draw_tree(self)._repr_svg_()
#
# ModuleNotFoundError: No module named 'svgling'
# Tree('S', [('The', 'DT'), ('us', 'PRP'), ('president', 'NN'), ('stays', 'NNS'), ('in', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Whitehouse', 'NNP')])])

# %% [markdown]
# # NLG : Natural Language Generation
# #### pip install wordcloud

# %%
# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Create a list of word
text=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")

# %%
# create the word cloud object

wordcloud = WordCloud (width=420,height=200,margin=2,background_color='black',colormap='Accent',mode='RGBA').generate(text)

# %%
plt.imshow(wordcloud,interpolation='quadric')
plt.axis("off")
plt.margins(x=0,y=0)
plt.show()

# %%
import numpy as np
from PIL import Image
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Load your light bulb mask image
bulb_mask = np.array(Image.open("bg_white_bulb.png"))

# Define your text data
# text = "innovation idea creativity brain technology lightbulb focus design smart future"

# Generate the word cloud inside the mask boundary
wc=WordCloud(margin=0, mask=bulb_mask,contour_width=0,background_color='white',colormap='Accent',mode='RGBA')

wc = WordCloud(background_color="black", mask=bulb_mask, contour_width=1, contour_color='grey')
wc.generate(text)

# Display your creation
plt.imshow(wc, interpolation='quadric')
plt.axis("off")
plt.show()

# %%
import nltk
from nltk import pos_tag, word_tokenize, RegexpParser

# Download necessary NLTK data files (only need to do this once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Sample text
text = "full stack datasceince, generative ai, agenti ai, llm model keep increase by different compnay"

# Tokenize the text
tokens = word_tokenize(text)

# Perform part-of-speech tagging
tagged_tokens = pos_tag(tokens)

# Define a chunk grammar
chunk_grammar = r"""
  NP: {<DT>?<JJ>*<NN>}   # Noun Phrase
  VP: {<VB.*><NP|PP>*}    # Verb Phrase
  PP: {<IN><NP>}          # Prepositional Phrase
"""

# Create a chunk parser
chunk_parser = RegexpParser(chunk_grammar)

# Parse the tagged tokens
chunked = chunk_parser.parse(tagged_tokens)

# Print the chunked output
print(chunked)

# Optionally, you can visualize the chunks
chunked.draw()
# Out:
# [nltk_data] Downloading package punkt to /Users/chandra/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/chandra/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# (S
#   (NP full/JJ stack/NN)
#   (NP datasceince/NN)
#   ,/,
#   (NP generative/JJ ai/NN)
#   ,/,
#   (NP agenti/NN)
#   (NP ai/NN)
#   ,/,
#   (NP llm/JJ model/NN)
#   (VP keep/VB (NP increase/NN))
#   (PP by/IN (NP different/JJ compnay/NN)))

# %% [markdown]
# # DAY 4 : 08032026 : NLP

# %%
from sklearn.feature_extraction.text import CountVectorizer
sentence='data science and ai genai has great careen ahead data science and genai'
count_vectorizer = CountVectorizer()
vector = count_vectorizer.fit_transform([sentence])
vector.toarray()
# Out:
# array([[1, 1, 2, 1, 2, 2, 1, 1, 2]])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
sentence='data science and ai genai has great careen ahead data science and genai'
tfid_vectorizer = TfidfVectorizer()
vector = tfid_vectorizer.fit_transform([sentence])
vector.toarray()
# Out:
# array([[0.21821789, 0.21821789, 0.43643578, 0.21821789, 0.43643578,
#         0.43643578, 0.21821789, 0.21821789, 0.43643578]])
