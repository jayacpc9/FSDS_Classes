# %% [markdown]
# # Data Structure
# ### list
# ### tuple
# ### set
# ### dict
# ### range

# %%
l =[] # list is defined with [] square brackets.
l # returns empty list
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
l = [10,20,30,40]
print(f"List  = {l}")
print(f"length of list = {len(l)}")
# Out:
# List  = [10, 20, 30, 40]
# length of list = 4

# %%
l.append(50) # append to the end of list
l.append(60) # list is growable/ can append any number of values
l.append(10) # allows duplicate vlues

print(f"List  = {l}")
print(f"length of list = {len(l)}")
# Out:
# List  = [10, 20, 30, 40, 50, 60, 10]
# length of list = 7

# %%
l.append([70,80,90,100,110,120])# nested list, list inside a list
l.append(['a','b','c','d','e','f']) # list can accpet mixed data types.

print(f"List  = {l}")
print(f"length of list = {len(l)}")
# Out:
# List  = [10, 20, 30, 40, 50, 60, 10, [70, 80, 90, 100, 110, 120], ['a', 'b', 'c', 'd', 'e', 'f']]
# length of list = 9

# %%
l2 = ['name',45,5890.75,25+2j,True]
print(f"List  = {l2}")
print(f"length of list = {len(l2)}")
# Out:
# List  = ['name', 45, 5890.75, (25+2j), True]
# length of list = 5

# %%
print(id(l)) # id of the list
print(id(l2))# id of thel ist will be different cos they are different indtance
# Out:
# 4518088320
# 4518091968

# %%
print(type(l))
print(type(l2))
# Out:
# <class 'list'>
# <class 'list'>

# %%
# list membership
print(10 in l )# check if 10 exists in list l
l
# Out:
# True
# [10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  10,
#  [70, 80, 90, 100, 110, 120],
#  ['a', 'b', 'c', 'd', 'e', 'f']]

# %%
['a', 'b', 'c', 'd', 'e', 'f'] in l
# Out:
# True

# %%
print(f"List  l2 = {l2}")
l3 = l2.copy()
print(f"List  l3  is a copy of l2 = {l3}")
l4 = l2
print(f"Id of l2 = {id(l2)}")
print(f"Id of l4 = {id(l4)}")
print(f"Id of l3 = {id(l3)}")
# Out:
# List  l2 = ['name', 45, 5890.75, (25+2j), True]
# List  l3  is a copy of l2 = ['name', 45, 5890.75, (25+2j), True]
# Id of l2 = 4518091968
# Id of l4 = 4518091968
# Id of l3 = 4518091648

# %%
print(f"List  l = {l}")
print(f"List  l2 = {l2}")
print(f"List  l3 = {l3}")
print(f"List  l4 = {l4}")
l1= l.copy()
# Out:
# List  l = [10, 20, 30, 40, 50, 60, 10, [70, 80, 90, 100, 110, 120], ['a', 'b', 'c', 'd', 'e', 'f']]
# List  l2 = ['name', 45, 5890.75, (25+2j), True]
# List  l3 = ['name', 45, 5890.75, (25+2j), True]
# List  l4 = ['name', 45, 5890.75, (25+2j), True]

# %%
# l.clear() # clears the full list

# %%
print(f"List  l = {l}")
print(f"List  l1 = {l1}")
print(f"List  l2 = {l2}")
print(f"List  l3 = {l3}")
print(f"List  l4 = {l4}")
# Out:
# List  l = [10, 20, 30, 40, 50, 60, 10, [70, 80, 90, 100, 110, 120], ['a', 'b', 'c', 'd', 'e', 'f']]
# List  l1 = [10, 20, 30, 40, 50, 60, 10, [70, 80, 90, 100, 110, 120], ['a', 'b', 'c', 'd', 'e', 'f']]
# List  l2 = ['name', 45, 5890.75, (25+2j), True]
# List  l3 = ['name', 45, 5890.75, (25+2j), True]
# List  l4 = ['name', 45, 5890.75, (25+2j), True]

# %%
# del l
# print(f"List  l = {l}")

# %%
l1.count(10) # returns the count of given value in the list
# to know how many time a value is repeated in the list
# Out:
# 2

# %%
l[:]
# Out:
# List  l = [10, 20, 30, 40, 50, 60, 10, [70, 80, 90, 100, 110, 120], ['a', 'b', 'c', 'd', 'e', 'f']]
# [10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  10,
#  [70, 80, 90, 100, 110, 120],
#  ['a', 'b', 'c', 'd', 'e', 'f']]

# %%
l[-1]
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
l[4:]
# Out:
# [50, 60, 10, [70, 80, 90, 100, 110, 120], ['a', 'b', 'c', 'd', 'e', 'f']]

# %%
l[3:-1]
# Out:
# [40, 50, 60, 10, [70, 80, 90, 100, 110, 120]]

# %%
l[0:10:3] # skip by 3 for index 0 to 10
# Out:
# [10, 40, 10]

# %%
l[::1]
# Out:
# [10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  10,
#  [70, 80, 90, 100, 110, 120],
#  ['a', 'b', 'c', 'd', 'e', 'f']]

# %%
l[::2] # all list by set 2
# Out:
# [10, 30, 50, 10, ['a', 'b', 'c', 'd', 'e', 'f']]

# %%
l[::3] # list all 3rd element from index to end of list.
# Out:
# [10, 40, 10]

# %%
l[::-1]
# Out:
# [['a', 'b', 'c', 'd', 'e', 'f'],
#  [70, 80, 90, 100, 110, 120],
#  10,
#  60,
#  50,
#  40,
#  30,
#  20,
#  10]

# %%
l[::-2]
# Out:
# [['a', 'b', 'c', 'd', 'e', 'f'], 10, 50, 30, 10]

# %%
l[::-3]
# Out:
# [['a', 'b', 'c', 'd', 'e', 'f'], 60, 30]

# %%
l
# Out:
# [10,
#  20,
#  30,
#  40,
#  50,
#  60,
#  10,
#  [70, 80, 90, 100, 110, 120],
#  ['a', 'b', 'c', 'd', 'e', 'f']]

# %%
l[4:-2]
# Out:
# [50, 60, 10]
