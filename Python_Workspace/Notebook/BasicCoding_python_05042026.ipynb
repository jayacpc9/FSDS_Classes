# %%
# Error types: compile time , runtime and logical errors
# Name of errors : 
# SyntaxError
#

# %%
import keyword as kw
print("Here are all the keywords in Pythons : ")
print(kw.kwlist)
print(f"\nThe total number of keywords  = {len(kw.kwlist)}")
# Out:
# Here are all the keywords in Pythons :
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
#
# The total number of keywords  = 35

# %%
print(f"kw.softkwlist = {kw.softkwlist}")
print(f"Checking keyword \"if\" = {kw.iskeyword("if")}")
print(f"Checking soft keyword \"case\" =  = {kw.issoftkeyword("case")}")
print(f"Checking soft keyword \"casing\" =  = {kw.issoftkeyword("casing")}")
# Out:
# kw.softkwlist = ['_', 'case', 'match', 'type']
# Checking keyword "if" = True
# Checking soft keyword "case" =  = True
# Checking soft keyword "casing" =  = False

# %%
# Data Types : int
i =5
print(type(i)) # return the data type of the given variable
# Out:
# <class 'int'>

# %%
# Data Type : float
f= 100.59
print(type(f)) 

# Data Type : exponential ( 2e0 thta is 2 X e power 0 that is )
f = 2e0
print(f)

f = 2e1 # 
print(f)

f = 2e2
print(f)

f = 2e-3
print(f)

f = 2.4e2
print(f)
# Out:
# <class 'float'>
# 2.0
# 20.0
# 200.0
# 0.002
# 240.0

# %%
# Data Type : bool
b = True
print(b)
print(type(b))

b = False
print(b)

b = None
print(b)

b1 = True+False # it will try to add the value True = 1 and False = 0, therefore it will be 1+0
print(b1)

t= True
f = False
print(t+f)
print(t-f)
print(t*f)
print(f/t)
print(f//t)

# print(t/f) # ZeroDivisionError: division by zero
# Out:
# True
# <class 'bool'>
# False
# None
# 1
# 1
# 1
# 0
# 0.0
# 0

# %%
# Data Type : comples 
# This data type is not available in any other programming language
    # for example : a+bj (c = 10+20j)
        # a - real part
        # b - imaginary part
        # j - squre root of -1

c = 10+20j
print(type(c))
print(f" The real part = c.real = {c.real}")
print(f" The imaginary part = c.imag = {c.imag}")
print(f" The conjugate part = c.conjugate = {c.conjugate()}")



d = 20 +30j

print(c+d) # since python is a dynamic programming language 
           # so it understands that real will be merged with real and imaginary with imaginary
# Out:
# <class 'complex'>
#  The real part = c.real = 10.0
#  The imaginary part = c.imag = 20.0
#  The conjugate part = c.conjugate = <built-in method conjugate of complex object at 0x10b4eabd0>
# (30+50j)
