# %%
import sys as s
print(f"Copyright : {s.copyright}")
print(f"Version : {s.version}")
print(f"Version info : {s.version_info}")
print(f"Api Version : {s.api_version}")
# Out:
# Copyright : Copyright (c) 2001-2024 Python Software Foundation.
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved.
# Version : 3.13.2 (v3.13.2:4f8bb3947cf, Feb  4 2025, 11:51:10) [Clang 15.0.0 (clang-1500.3.9.4)]
# Version info : sys.version_info(major=3, minor=13, micro=2, releaselevel='final', serial=0)
# Api Version : 1013

# %%
print(3+2)
# Out:
# 5

# %%
print(3*3) # multiplication (\(3 \times 2\)).
# Out:
# 9

# %%
print(3**2) # exponentiation ((3^{2}) 3 to the power of 2 or 3 square.
print(2**3) # 2 to the power of 3 or 2 cube
# Out:
# 9
# 8

# %%
print(10*3-2+1)# BODMAS : 
               # Brackets
               # Orders(Exponents/Powers) 
               # Division, Multiplication(Equal priority; left to right)
               # Addition & Subtraction(Equal priority; left to right)
# Out:
# 29

# %%
print(10*3-(2+1))
# Out:
# 27

# %%
# 05/04/2026
# working with text

# %%
singleQuote = 'apple'
doubleQuote = "apple"
trippleSingleQuotes = '''This is a sample of large text and it's usage.
We can put any size text 
in any format and it 
will still accept it.
Jus the way we have this long string.!'''

trippleQuote = """This is a sample of large text and it's usage.
We can put any size text in any format and it will still accept it.
Jus the way we have this long string.!"""

print(singleQuote)
print(trippleSingleQuotes)
print(doubleQuote)
print(trippleQuote)
# Out:
# apple
# This is a sample of large text and it's usage.
# We can put any size text
# in any format and it
# will still accept it.
# Jus the way we have this long string.!
# apple
# This is a sample of large text and it's usage.
# We can put any size text in any format and it will still accept it.
# Jus the way we have this long string.!

# %%
'''This is a sample of large text and it's usage.
We can put any size text 
in any format and it 
will still accept it.
Jus the way we have this long string.!'''
# Out:
# "This is a sample of large text and it's usage.\nWe can put any size text \nin any format and it \nwill still accept it.\nJus the way we have this long string.!"

# %%
value1 =5
print(id(value1)) # id is a function that is used to get the address of the given variable. 
                  # or returns address of the memory location.
value2 =10
print(id(value2))
# Out:
# 4334873360
# 4334873520

# %%
# variables : 
    # they are case sensitivie
    # does not accept digits at the start
    # they can have digits at the end or middle of variable names
    # does not accept any special character, except underscore _
    # keyword (Reserved word) : keywords cannot be defined as variables, the following are the keywords in python:
        # ['False','None','True','and','as','assert','async','await','break','class','continue',
        # 'def','del','elif','else','except','finally','for','from','global','if','import','in','is','lambda',...'return',
        # 'try', 'while', 'with', 'yield']
    # import keyword as kw  use the kw.kwlist to get the list of all keywords

# %%
import keyword as kw
kw.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']
