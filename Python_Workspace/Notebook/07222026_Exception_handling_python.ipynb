# %% [markdown]
# # Python Exception handling
# ### - compile time error
# ### - logical error
# ### - runtime error
#
# # try:
# #   print(c/d)
# # except Exception":
# #   print("Cannot divide number by zero")

# %%
import pandas as pd

# %%
a = 5
b =2
print(a/b)
print('bye')
# Out:
# 2.5
# bye

# %%
c = 5
d = 0
print(d/c)
print('bye')
# Out:
# 0.0
# bye

# %%
print(c/d)
print('bye')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(c/d)
#       2 print('bye')
#
# ZeroDivisionError: division by zero

# %%
c = 5
d = 0

try:
  print(c/d)
except Exception as e:
  print("Cannot divide number by zero") 

print('bye')
# Out:
# Cannot divide number by zero
# bye

# %%
c = 5
d = 0

try:
  print(c/d)
except Exception as e:
  print("Cannot divide number by zero : ",e) 
  e.print

print('bye')
# Out:
# Cannot divide number by zero :  division by zero
# bye

# %%
c = 5
d = 0

try:
  print(c/d)
except Exception as e:
  print("Cannot divide number by zero : ",e)
# Out:
# Cannot divide number by zero :  division by zero

# %%
c = 5
d = 0

try:
  print("Resource : OPEN")
  print(c/d)
  print("Resource : Calculations DONE")
except Exception as e:
  print("Cannot divide number by zero : ",e) 
finally:
  print("Bye ! in finally block: Resource : CLOSED")
# Out:
# Resource : OPEN
# Cannot divide number by zero :  division by zero
# Bye ! in finally block: Resource : CLOSED

# %% [markdown]
# # Stop iteration
