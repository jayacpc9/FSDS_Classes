# %% [markdown]
# # Pandas

# %%
import pandas as pd
print("Pandas Version  = ",pd.__version__)
# Out:
# Pandas Version  =  2.3.3

# %%
pd_version =pd.show_versions() # more details use this
print("As Jason : ",pd_version)
# Out:
# INSTALLED VERSIONS
# ------------------
# commit                : 9c8bc3e55188c8aff37207a74f1dd144980b8874
# python                : 3.13.9
# python-bits           : 64
# OS                    : Darwin
# OS-release            : 23.0.0
# Version               : Darwin Kernel Version 23.0.0: Fri Sep 15 14:43:05 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6020
# machine               : arm64
# processor             : arm
# byteorder             : little
# LC_ALL                : None
# LANG                  : None
# LOCALE                : None.UTF-8
#
# pandas                : 2.3.3
# numpy                 : 2.3.5
# pytz                  : 2025.2
# dateutil              : 2.9.0.post0
# pip                   : 25.3
# Cython                : None
# sphinx                : 8.2.3
# IPython               : 9.7.0
# adbc-driver-postgresql: None
# adbc-driver-sqlite    : None
# bs4                   : 4.13.5
# blosc                 : None
# bottleneck            : 1.4.2
# ...

# %%
pd_version =pd.show_versions(as_json= True) # more details use this
print("As Jason : ",pd_version)
# Out:
# {
#   "system": {
#     "commit": "9c8bc3e55188c8aff37207a74f1dd144980b8874",
#     "python": "3.13.9",
#     "python-bits": 64,
#     "OS": "Darwin",
#     "OS-release": "23.0.0",
#     "Version": "Darwin Kernel Version 23.0.0: Fri Sep 15 14:43:05 PDT 2023; root:xnu-10002.1.13~1/RELEASE_ARM64_T6020",
#     "machine": "arm64",
#     "processor": "arm",
#     "byteorder": "little",
#     "LC_ALL": null,
#     "LANG": null,
#     "LOCALE": {
#       "language-code": null,
#       "encoding": "UTF-8"
#     }
#   },
#   "dependencies": {
#     "pandas": "2.3.3",
#     "numpy": "2.3.5",
#     "pytz": "2025.2",
#     "dateutil": "2.9.0.post0",
#     "pip": "25.3",
#     "Cython": null,
#     "sphinx": "8.2.3",
#     "IPython": "9.7.0",
#     "adbc-driver-postgresql": null,
#     "adbc-driver-sqlite": null,
#     "bs4": "4.13.5",
#     "blosc": null,
#     "bottleneck": "1.4.2",
#     "dataframe-api-compat": null,
#     "fastparquet": null,
#     "fsspec": "2025.10.0",
# ...

# %%
# ?pd

# %% [markdown]
# # Pandas POC : country economy analysis

# %%
# Data set/File location
folder_name ='/Users/chandra/Desktop/FSDS_GenAI_Training/FSDS_Classes/Python_Workspace/assets/'
file_name ='data.xlsx'

file_location =folder_name+file_name # Excel Data file location

# %%
df = pd.read_excel(file_location)
df # prints first 5 and last 5 values from the data frame.
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0    Hong Kong SAR, China         HKG      7.900        74.2000
# 1                Portugal         PRT      7.900        62.0956
# 2                   Japan         JPN      8.200        89.7100
# 3                 Germany         DEU      8.500        84.1700
# 4                  Greece         GRC      8.500        59.8663
# ..                    ...         ...        ...            ...
# 190                  Mali         MLI     44.138         3.5000
# 191               Burundi         BDI     44.151         1.3000
# 192                  Chad         TCD     45.745         2.3000
# 193                Angola         AGO     45.985        19.1000
# 194                 Niger         NER     49.661         1.7000
#
#              IncomeGroup
# 0            High income
# 1            High income
# 2            High income
# 3            High income
# 4            High income
# ..                   ...
# ...

# %%
len(df)
# Out:
# 195

# %%
df.shape # dimension of the data frame(rows and columns)
# Out:
# (195, 5)

# %%
df.head() # will provide only the top 5 rows by default.
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0  Hong Kong SAR, China         HKG        7.9        74.2000  High income
# 1              Portugal         PRT        7.9        62.0956  High income
# 2                 Japan         JPN        8.2        89.7100  High income
# 3               Germany         DEU        8.5        84.1700  High income
# 4                Greece         GRC        8.5        59.8663  High income

# %%
df.head(2) # to print only a limited number of rows
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0  Hong Kong SAR, China         HKG        7.9        74.2000  High income
# 1              Portugal         PRT        7.9        62.0956  High income

# %%
df.tail() # bottom 5 rows
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 190        Mali         MLI     44.138            3.5           Low income
# 191     Burundi         BDI     44.151            1.3           Low income
# 192        Chad         TCD     45.745            2.3           Low income
# 193      Angola         AGO     45.985           19.1  Upper middle income
# 194       Niger         NER     49.661            1.7           Low income

# %%
df.tail(2) # bottom 2 rows
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 193      Angola         AGO     45.985           19.1  Upper middle income
# 194       Niger         NER     49.661            1.7           Low income

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df.columns # provides all the column names.
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
len(df.columns) # length of columns
# Out:
# 5

# %%
df.dtypes # all the data types of the dataframe.
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df['CountryName']
# Out:
# 0      Hong Kong SAR, China
# 1                  Portugal
# 2                     Japan
# 3                   Germany
# 4                    Greece
#                ...
# 190                    Mali
# 191                 Burundi
# 192                    Chad
# 193                  Angola
# 194                   Niger
# Name: CountryName, Length: 195, dtype: object

# %%
df.CountryName
# Out:
# 0      Hong Kong SAR, China
# 1                  Portugal
# 2                     Japan
# 3                   Germany
# 4                    Greece
#                ...
# 190                    Mali
# 191                 Burundi
# 192                    Chad
# 193                  Angola
# 194                   Niger
# Name: CountryName, Length: 195, dtype: object

# %%
df['CountryCode']
# Out:
# 0      HKG
# 1      PRT
# 2      JPN
# 3      DEU
# 4      GRC
#       ...
# 190    MLI
# 191    BDI
# 192    TCD
# 193    AGO
# 194    NER
# Name: CountryCode, Length: 195, dtype: object

# %%
df[['BirthRate','InternetUsers']]
# Out:
#      BirthRate  InternetUsers
# 0        7.900        74.2000
# 1        7.900        62.0956
# 2        8.200        89.7100
# 3        8.500        84.1700
# 4        8.500        59.8663
# ..         ...            ...
# 190     44.138         3.5000
# 191     44.151         1.3000
# 192     45.745         2.3000
# 193     45.985        19.1000
# 194     49.661         1.7000
#
# [195 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %% [markdown]
# # Seperating numerical and categorical data.
# # numerical data : numbers/numerical data
# # categorical data : text/string/alphanumeric data

# %%
df_numerical_data = df[['BirthRate','InternetUsers']]
df_categorical_data = df[['CountryName', 'CountryCode','IncomeGroup']]

# %%
df_categorical_data.head(1)
# Out:
#             CountryName CountryCode  IncomeGroup
# 0  Hong Kong SAR, China         HKG  High income

# %%
df_numerical_data.head(1)
# Out:
#    BirthRate  InternetUsers
# 0        7.9           74.2

# %%
df.head(1) # full data to confirm
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0  Hong Kong SAR, China         HKG        7.9           74.2  High income

# %%
print(df.shape)
print(df_numerical_data.shape)
print(df_categorical_data.shape)
# Out:
# (195, 5)
# (195, 2)
# (195, 3)

# %%
print(df.columns)
print("-"*50)
print(df_numerical_data.columns)
print(df_categorical_data.columns)
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')
# --------------------------------------------------
# Index(['BirthRate', 'InternetUsers'], dtype='object')
# Index(['CountryName', 'CountryCode', 'IncomeGroup'], dtype='object')

# %%
df[:] # slicing
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0    Hong Kong SAR, China         HKG      7.900        74.2000
# 1                Portugal         PRT      7.900        62.0956
# 2                   Japan         JPN      8.200        89.7100
# 3                 Germany         DEU      8.500        84.1700
# 4                  Greece         GRC      8.500        59.8663
# ..                    ...         ...        ...            ...
# 190                  Mali         MLI     44.138         3.5000
# 191               Burundi         BDI     44.151         1.3000
# 192                  Chad         TCD     45.745         2.3000
# 193                Angola         AGO     45.985        19.1000
# 194                 Niger         NER     49.661         1.7000
#
#              IncomeGroup
# 0            High income
# 1            High income
# 2            High income
# 3            High income
# 4            High income
# ..                   ...
# ...

# %%
df[:10]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0    Hong Kong SAR, China         HKG      7.900        74.2000
# 1                Portugal         PRT      7.900        62.0956
# 2                   Japan         JPN      8.200        89.7100
# 3                 Germany         DEU      8.500        84.1700
# 4                  Greece         GRC      8.500        59.8663
# 5                   Italy         ITA      8.500        58.4593
# 6             Korea, Rep.         KOR      8.600        84.7700
# 7                 Romania         ROU      8.800        49.7645
# 8  Bosnia and Herzegovina         BIH      9.062        57.7900
# 9                   Spain         ESP      9.100        71.6350
#
#            IncomeGroup
# 0          High income
# 1          High income
# 2          High income
# 3          High income
# 4          High income
# 5          High income
# 6          High income
# 7  Upper middle income
# 8  Upper middle income
# ...

# %%
df[10:11] # to print the 10th record, slicing from 10 to 11
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 10    Bulgaria         BGR        9.2        53.0615  Upper middle income

# %%
df[0:100:20] # print from 0 to 100 step by 20
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  \
# 0   Hong Kong SAR, China         HKG      7.900        74.2000
# 20             Lithuania         LTU     10.100        68.4529
# 40        Macedonia, FYR         MKD     11.222        65.2400
# 60               Armenia         ARM     13.308        41.9000
# 80   Antigua and Barbuda         ATG     16.447        63.4000
#
#             IncomeGroup
# 0           High income
# 20          High income
# 40  Upper middle income
# 60  Lower middle income
# 80          High income

# %%
df[::5]# print 0 to end step by 5
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0    Hong Kong SAR, China         HKG      7.900        74.2000
# 5                   Italy         ITA      8.500        58.4593
# 10               Bulgaria         BGR      9.200        53.0615
# 15                Austria         AUT      9.400        80.6188
# 20              Lithuania         LTU     10.100        68.4529
# 25            Netherlands         NLD     10.200        93.9564
# 30                   Cuba         CUB     10.400        27.9300
# 35              Mauritius         MUS     10.900        39.0000
# 40         Macedonia, FYR         MKD     11.222        65.2400
# 45             Montenegro         MNE     11.616        60.3100
# 50               Barbados         BRB     12.188        73.0000
# 55          United States         USA     12.500        84.2000
# 60                Armenia         ARM     13.308        41.9000
# 65                Jamaica         JAM     13.540        37.1000
# ...

# %%
df[::-1] # reversing the order or list
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194                 Niger         NER     49.661         1.7000
# 193                Angola         AGO     45.985        19.1000
# 192                  Chad         TCD     45.745         2.3000
# 191               Burundi         BDI     44.151         1.3000
# 190                  Mali         MLI     44.138         3.5000
# ..                    ...         ...        ...            ...
# 4                  Greece         GRC      8.500        59.8663
# 3                 Germany         DEU      8.500        84.1700
# 2                   Japan         JPN      8.200        89.7100
# 1                Portugal         PRT      7.900        62.0956
# 0    Hong Kong SAR, China         HKG      7.900        74.2000
#
#              IncomeGroup
# 194           Low income
# 193  Upper middle income
# 192           Low income
# 191           Low income
# 190           Low income
# ..                   ...
# ...

# %%
df[::-5]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 194                     Niger         NER     49.661         1.7000
# 189                   Somalia         SOM     43.891         1.5000
# 184                    Zambia         ZMB     40.471        15.4000
# 179                   Senegal         SEN     38.533        13.1000
# 174               South Sudan         SSD     37.126        14.1000
# 169               Timor-Leste         TLS     35.755         1.1000
# 164                     Kenya         KEN     35.194        39.0000
# 159  Central African Republic         CAF     34.076         3.5000
# 154                  Ethiopia         ETH     32.925         1.9000
# 149                     Gabon         GAB     30.555         9.2000
# 144                  Kiribati         KIR     29.044        11.5000
# 139           Kyrgyz Republic         KGZ     27.200        23.0000
# 134                  Djibouti         DJI     25.486         9.5000
# ...

# %%
df.isnull() # it will check if there are any missing values in the dataframe
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isna() # check if there are any na values
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.describe() # this is used for descriptive statistics and will return numerical data only by default.
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_numerical_data.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_categorical_data.describe()
# Out:
#                  CountryName CountryCode  IncomeGroup
# count                    195         195          195
# unique                   195         195            4
# top     Hong Kong SAR, China         HKG  High income
# freq                       1           1           67

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.columns=['a','b','c','d','e'] # changing the column name to a,b,c,

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df
# Out:
#                         a    b       c        d                    e
# 0    Hong Kong SAR, China  HKG   7.900  74.2000          High income
# 1                Portugal  PRT   7.900  62.0956          High income
# 2                   Japan  JPN   8.200  89.7100          High income
# 3                 Germany  DEU   8.500  84.1700          High income
# 4                  Greece  GRC   8.500  59.8663          High income
# ..                    ...  ...     ...      ...                  ...
# 190                  Mali  MLI  44.138   3.5000           Low income
# 191               Burundi  BDI  44.151   1.3000           Low income
# 192                  Chad  TCD  45.745   2.3000           Low income
# 193                Angola  AGO  45.985  19.1000  Upper middle income
# 194                 Niger  NER  49.661   1.7000           Low income
#
# [195 rows x 5 columns]

# %%
df.columns =['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup']
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0    Hong Kong SAR, China         HKG      7.900        74.2000
# 1                Portugal         PRT      7.900        62.0956
# 2                   Japan         JPN      8.200        89.7100
# 3                 Germany         DEU      8.500        84.1700
# 4                  Greece         GRC      8.500        59.8663
# ..                    ...         ...        ...            ...
# 190                  Mali         MLI     44.138         3.5000
# 191               Burundi         BDI     44.151         1.3000
# 192                  Chad         TCD     45.745         2.3000
# 193                Angola         AGO     45.985        19.1000
# 194                 Niger         NER     49.661         1.7000
#
#              IncomeGroup
# 0            High income
# 1            High income
# 2            High income
# 3            High income
# 4            High income
# ..                   ...
# ...

# %%
# multiplying 2 attribuites
df['myCalc'] = df.BirthRate * df.InternetUsers
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0    Hong Kong SAR, China         HKG      7.900        74.2000
# 1                Portugal         PRT      7.900        62.0956
# 2                   Japan         JPN      8.200        89.7100
# 3                 Germany         DEU      8.500        84.1700
# 4                  Greece         GRC      8.500        59.8663
# ..                    ...         ...        ...            ...
# 190                  Mali         MLI     44.138         3.5000
# 191               Burundi         BDI     44.151         1.3000
# 192                  Chad         TCD     45.745         2.3000
# 193                Angola         AGO     45.985        19.1000
# 194                 Niger         NER     49.661         1.7000
#
#              IncomeGroup     myCalc
# 0            High income  586.18000
# 1            High income  490.55524
# 2            High income  735.62200
# 3            High income  715.44500
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup  \
# 0  Hong Kong SAR, China         HKG        7.9        74.2000  High income
# 1              Portugal         PRT        7.9        62.0956  High income
# 2                 Japan         JPN        8.2        89.7100  High income
# 3               Germany         DEU        8.5        84.1700  High income
# 4                Greece         GRC        8.5        59.8663  High income
#
#       myCalc
# 0  586.18000
# 1  490.55524
# 2  735.62200
# 3  715.44500
# 4  508.86355

# %%
df=df.drop('myCalc',axis= 1)

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0  Hong Kong SAR, China         HKG        7.9        74.2000  High income
# 1              Portugal         PRT        7.9        62.0956  High income
# 2                 Japan         JPN        8.2        89.7100  High income
# 3               Germany         DEU        8.5        84.1700  High income
# 4                Greece         GRC        8.5        59.8663  High income

# %%
df['InternetUsers'] <2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191     True
# 192    False
# 193    False
# 194     True
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[df.InternetUsers < 2]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 89        Myanmar         MMR     18.119            1.6  Lower middle income
# 154      Ethiopia         ETH     32.925            1.9           Low income
# 163       Eritrea         ERI     34.800            0.9           Low income
# 169   Timor-Leste         TLS     35.755            1.1  Lower middle income
# 172  Sierra Leone         SLE     36.729            1.7           Low income
# 177        Guinea         GIN     37.337            1.6           Low income
# 189       Somalia         SOM     43.891            1.5           Low income
# 191       Burundi         BDI     44.151            1.3           Low income
# 194         Niger         NER     49.661            1.7           Low income

# %%
len(df[df.InternetUsers < 2]) # List all countries with internet users less than 2
# Out:
# 9

# %%
df[df.BirthRate > 40]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 183           Nigeria         NGA     40.045           38.0
# 184            Zambia         ZMB     40.471           15.4
# 185      Burkina Faso         BFA     40.551            9.1
# 186  Congo, Dem. Rep.         COD     42.394            2.2
# 187       Gambia, The         GMB     42.525           14.0
# 188            Uganda         UGA     43.474           16.2
# 189           Somalia         SOM     43.891            1.5
# 190              Mali         MLI     44.138            3.5
# 191           Burundi         BDI     44.151            1.3
# 192              Chad         TCD     45.745            2.3
# 193            Angola         AGO     45.985           19.1
# 194             Niger         NER     49.661            1.7
#
#              IncomeGroup
# 183  Lower middle income
# 184  Lower middle income
# 185           Low income
# 186           Low income
# 187           Low income
# 188           Low income
# ...

# %%
len(df[df.BirthRate > 40]) # How many countries have birth rate greater than 40
# Out:
# 12

# %%
df[(df.BirthRate >40) & (df.InternetUsers < 2)] # all countries where birthrate is > 40 and internet useage is < 2
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 189     Somalia         SOM     43.891            1.5  Low income
# 191     Burundi         BDI     44.151            1.3  Low income
# 194       Niger         NER     49.661            1.7  Low income

# %%
len(df[(df.BirthRate >40) & (df.InternetUsers < 2)])
# Out:
# 3

# %% [markdown]
# # 05262026 : Day 2 : Pandas - cont..

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0    Hong Kong SAR, China         HKG      7.900        74.2000
# 1                Portugal         PRT      7.900        62.0956
# 2                   Japan         JPN      8.200        89.7100
# 3                 Germany         DEU      8.500        84.1700
# 4                  Greece         GRC      8.500        59.8663
# ..                    ...         ...        ...            ...
# 190                  Mali         MLI     44.138         3.5000
# 191               Burundi         BDI     44.151         1.3000
# 192                  Chad         TCD     45.745         2.3000
# 193                Angola         AGO     45.985        19.1000
# 194                 Niger         NER     49.661         1.7000
#
#              IncomeGroup
# 0            High income
# 1            High income
# 2            High income
# 3            High income
# 4            High income
# ..                   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %% [markdown]
# # How to get the unique values from the DF

# %%
df['IncomeGroup'].unique() # returns the unique items in the given row.
# Out:
# array(['High income', 'Upper middle income', 'Lower middle income',
#        'Low income'], dtype=object)

# %%
df['IncomeGroup'].nunique() # nunique will return the number of unique values.
# Out:
# 4

# %%
HIGH_INCOME = 'High income'
UPPER_MIDDLE_INCOME='Upper middle income'
LOWER_MIDDLE_INCOME='Lower middle income',
LOWER_INCOME = 'Low income'

df[df.IncomeGroup == HIGH_INCOME]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0    Hong Kong SAR, China         HKG      7.900        74.2000  High income
# 1                Portugal         PRT      7.900        62.0956  High income
# 2                   Japan         JPN      8.200        89.7100  High income
# 3                 Germany         DEU      8.500        84.1700  High income
# 4                  Greece         GRC      8.500        59.8663  High income
# ..                    ...         ...        ...            ...          ...
# 104                  Oman         OMN     20.419        66.4500  High income
# 106                Kuwait         KWT     20.575        75.4600  High income
# 107          Saudi Arabia         SAU     20.576        60.5000  High income
# 114                Israel         ISR     21.300        70.8000  High income
# 166     Equatorial Guinea         GNQ     35.362        16.4000  High income
#
# [67 rows x 5 columns]

# %%
len(df[df.IncomeGroup == HIGH_INCOME])
# Out:
# 67

# %% [markdown]
# # numpy : nd array
# # Pandas : dataframes
# # matplotlib : visualization
# # Seaborn : statistical visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.rcParams['figure.figsize'] = 6,2

import warnings
warnings.filterwarnings('ignore') # os error

# %%
df.InternetUsers
plt.plot(df.InternetUsers)

# %%
vis1 =  sns.distplot(df['InternetUsers']) # using seaborn
plt.show()

# distplot : is distributed graph :
# univarient alnalysis : plot the graph using one variable
# Bivarient analysis : plotting the graph using two variables
# Multivarient analysis : plotting the graph using multiple variables

# %%
vis2 = sns.displot(df.InternetUsers) # there is no distrubution line/graph is not available in this graph

# %%
vis2 = sns.displot(df.InternetUsers, bins = 15)

# %% [markdown]
# # what is an outlier
# ### outlier : is the data point which is very far from other observation.
# ### outlier impact machine learning model accuracy
# ### outiier is also called as anomaly detection.
#
# # Hoto detect outlier?
# ### it is done easily by Visualization.

# %%
vis3 = sns.boxplot(data=df ,x = "IncomeGroup",y = "BirthRate")

# %%
vis4 = sns.lmplot(data = df,x ='InternetUsers', y ='BirthRate')

# %%
vis5 = sns.lmplot(data =df, x='InternetUsers',y='BirthRate',fit_reg=False)

# %%
vis5 = sns.lmplot(data =df, x='InternetUsers',y='BirthRate',fit_reg=False, hue = "IncomeGroup",palette="rocket")
# conclusion :   high income group people have lot of internet and less birthrate

# %%
vis6 = sns.catplot(data=df,y='BirthRate',x='InternetUsers', hue='IncomeGroup',)

# %%
sns.set_theme(style='white')

vis7 = sns.JointGrid(data=df,x='InternetUsers',y='BirthRate',hue='IncomeGroup')

# vis7.plot_joint(sns.kdeplot,fill=True, clip=((2200, 6800), (10, 25)),thresh=0, levels=100, cmap="rocket")
vis7.plot_joint(sns.kdeplot, fill=True, clip=((2200, 6800), (10, 25)), thresh=0, levels=2, cmap="rocket")
vis7.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)

# %%
sns.color_palette()
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]
