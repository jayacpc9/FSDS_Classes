# %%
from gtts import gTTS 
from IPython.display import Audio

text_to_speech = gTTS('''welcome to data science programme, gen ai & agentic ai programme 
                      under prakash senapati guidance. classes will help practicle exposure 
                      to boost up technical skill and increase learning of coding skills, to get job''', 
                      lang='hi',tld='com')
sound_file = 'text_to_speech_gtts.wav'

text_to_speech.save(sound_file)
Audio(sound_file, autoplay= False)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
