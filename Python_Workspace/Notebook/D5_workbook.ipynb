# %%
3+4
# Out:
# 7

# %%
_ * 2 # _ (underscore) is used for fetching the previoius value.
# in this case _ will return 7 due to the previous calculations
# Out:
# 10

# %%
12/3 #Float division
# Out:
# 4.0

# %%
12//3 # Floor Division
# Out:
# 4

# %%
print(13/5) # Float Division
print(13//5) # Floor Division
# Out:
# 2.6
# 2

# %%
4+5-10*3 # Always follows bodmas : brackets, Division, Multiplication, Addition, Subtraction
# Out:
# -21

# %%
# insall vs code & vs code extension -- blackbox agent | claude code
# codex | cline | jupyter | kilo code ai |office viewer | pylance python environement|
