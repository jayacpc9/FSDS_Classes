# %% [markdown]
# # Pandas

# %%
import pandas as pd
print("Pandas Version  = ",pd.__version__)

# pd_version =pd.show_versions() # more details use this
# print(pd_version)
# Out:
# Pandas Version  =  2.3.3
