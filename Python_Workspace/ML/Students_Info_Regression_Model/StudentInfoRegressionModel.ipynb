# %% [markdown]
# # Student info

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
folder_name ="./assets/"
file_name ="student_info.csv"
full_file_path = folder_name+file_name
print("full_file_path = ", full_file_path)
# Load the dataset

student_df = pd.read_csv(folder_name+file_name)
student_df
# Out:
# full_file_path =  ./assets/student_info.csv
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
student_df.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %%
student_df.tail()
# Out:
#      study_hours  student_marks
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50

# %%
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
student_df.describe()
# Out:
#        study_hours  student_marks
# count   195.000000      200.00000
# mean      6.995949       77.93375
# std       1.253060        4.92570
# min       5.010000       68.57000
# 25%       5.775000       73.38500
# 50%       7.120000       77.71000
# 75%       8.085000       82.32000
# max       8.990000       86.99000

# %%
plt.figure(figsize=(8,6))
plt.scatter(student_df.study_hours, student_df.student_marks)
plt.xlabel("Students Study Hours")
plt.ylabel("Student Marks")
plt.title("Student Study Hours and Marks")
plt.show()

# %% [markdown]
# ## Prepare the data for Machine Learning algorithms

# %%
student_df.isnull().sum()
# Out:
# study_hours      5
# student_marks    0
# dtype: int64

# %%
student_df.isna().sum()
# Out:
# study_hours      5
# student_marks    0
# dtype: int64

# %%
student_df.mean()
# Out:
# study_hours       6.995949
# student_marks    77.933750
# dtype: float64

# %%
student_df.median()
# Out:
# study_hours       7.12
# student_marks    77.71
# dtype: float64

# %%
student_df.std()
# Out:
# study_hours      1.25306
# student_marks    4.92570
# dtype: float64

# %%
std_df2=student_df.fillna(student_df.mean())
std_df2.head()
# Out:
#    study_hours  student_marks
# 0     6.830000          78.50
# 1     6.560000          76.74
# 2     6.995949          78.68
# 3     5.670000          71.82
# 4     8.670000          84.19

# %%
std_df2.isnull().sum()
# Out:
# study_hours      0
# student_marks    0
# dtype: int64

# %%
std_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    200 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
std_df2.columns
# Out:
# Index(['study_hours', 'student_marks'], dtype='object')

# %%
x = std_df2.drop('student_marks', axis='columns')
y = std_df2.drop('study_hours', axis='columns')

print("shape of X = ", x.shape)
print("shape of y = ", y.shape)
# Out:
# shape of X =  (200, 1)
# shape of y =  (200, 1)

# %%
x.head()
# Out:
#    study_hours
# 0     6.830000
# 1     6.560000
# 2     6.995949
# 3     5.670000
# 4     8.670000

# %%
y.head()
# Out:
#    student_marks
# 0          78.50
# 1          76.74
# 2          78.68
# 3          71.82
# 4          84.19

# %% [markdown]
# # Split data to train and test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)


print("shape of x_train = ", x_train.shape)
print("shape of y_train = ", y_train.shape)
print("shape of x_test = ", x_test.shape)
print("shape of y_test = ", y_test.shape)
# Out:
# shape of x_train =  (160, 1)
# shape of y_train =  (160, 1)
# shape of x_test =  (40, 1)
# shape of y_test =  (40, 1)

# %% [markdown]
# # Model selection

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
ls.get_params()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 ls.get_params()
#
# NameError: name 'ls' is not defined

# %%
m =lr.coef_
m
# Out:
# array([[3.93037294]])

# %%
c =lr.intercept_
c
# Out:
# array([50.45063632])

# %%
y1 = m *11 +c
print("y1 = " , y1.round(2))
# Out:
# y1 =  [[93.68]]

# %%
lr.predict([[11]]).round(2)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[93.68]])

# %%
lr
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x_test)
print("len(y_predict) = ",len(y_predict))
y_predict
# Out:
# len(y_predict) =  40
# array([[83.50507271],
#        [70.84927186],
#        [72.93236952],
#        [85.35234799],
#        [73.20749562],
#        [84.48766595],
#        [80.12495199],
#        [81.85431608],
#        [80.91102657],
#        [82.20804964],
#        [78.98514384],
#        [84.84139951],
#        [77.84533568],
#        [77.68812077],
#        [83.22994661],
#        [85.78468901],
#        [84.9593107 ],
#        [72.61793968],
#        [78.71001773],
#        [79.18166248],
#        [84.2911473 ],
#        [85.6274741 ],
#        [74.74034107],
#        [81.3433676 ],
#        [72.02838374],
#        [80.40007809],
#        [78.98514384],
#        [82.09013845],
#        [77.94732382],
#        [82.24735337],
#        [75.44780819],
#        [84.60557713],
#        [71.63534645],
#        [75.48711192],
#        [70.29901965],
#        [78.98514384],
#        [75.32989701],
#        [84.52696967],
#        [74.07217767],
#        [71.4388278 ]])

# %%
pd.DataFrame(np.c_[x_test, y_test, y_predict], columns = ['study_hours', 'student_marks_original','student_marks_predicted'])
# Out:
#     study_hours  student_marks_original  student_marks_predicted
# 0      8.410000                   82.50                83.505073
# 1      5.190000                   71.18                70.849272
# 2      5.720000                   73.25                72.932370
# 3      8.880000                   83.64                85.352348
# 4      5.790000                   73.64                73.207496
# 5      8.660000                   86.99                84.487666
# 6      7.550000                   81.18                80.124952
# 7      7.990000                   82.75                81.854316
# 8      7.750000                   79.50                80.911027
# 9      8.080000                   81.70                82.208050
# 10     7.260000                   79.41                78.985144
# 11     8.750000                   85.95                84.841400
# 12     6.970000                   77.19                77.845336
# ...

# %%
ls
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9521841793508595

# %%
lr.score(x_train,y_train)
# Out:
# 0.9584528455152638

# %%
plt.scatter(x_train,y_train)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_train,lr.predict(x_train),color='r')

# %% [markdown]
# # Create a pipeline and dump the regression model into a pickel file

# %%
import joblib
joblib.dump(lr,'Students_marks.pkl')
# Out:
# ['Students_marks.pkl']

# %%
lr_model=joblib.load('Students_marks.pkl')

# %%
lr_model.predict([[5]]).round(2)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[70.1]])

# %%
lr.predict([[5]])[0][0].round(2)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(70.1)

# %%
hours = 10
input_data = pd.DataFrame([[hours]], columns=["study_hours"])
lr_model.predict(input_data)[0][0].round(2)
# Out:
# np.float64(89.75)

# %%
# Save the trained model to disk
import pickle
filename = 'students_linear_regression_model.pkl'
with open(filename, 'wb') as file:
    pickle.dump(lr, file)
print(f"Model has been pickled and saved as {filename}")

import os
print(os.getcwd())
# Out:
# Model has been pickled and saved as students_linear_regression_model.pkl
# /Users/chandra/Desktop/FSDS_GenAI_Training/FSDS_Classes/Python_Workspace/ML/Students_Info_Regression_Model
