# %% [markdown]
# # Avacodo EDA

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# <a id="Creating-DataFrames"></a>
# # Creating DataFrames
# * From a list of dictionaries (constructed row by row)

# %%
list_of_dicts = [ 
     {"name": "Ginger", "breed": "Dachshund", "height_cm": 22,"weight_kg": 10, "date_of_birth": "2019-03-14"},
    {"name": "Scout", "breed": "Dalmatian", "height_cm": 59,"weight_kg": 25, "date_of_birth": "2019-05-09"}
]
new_dogs = pd.DataFrame(list_of_dicts)
new_dogs
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019-03-14
# 1   Scout  Dalmatian         59         25    2019-05-09

# %%
dict_of_lists = { 
     "name": ["Ginger", "Scout"], 
     "breed": ["Dachshund", "Dalmatian"], 
     "height_cm": [22, 59], 
     "weight_kg": [10, 25], 
     "date_of_birth": ["2019-03-14","2019-05-09"]  } 
new_dogs = pd.DataFrame(dict_of_lists) 
new_dogs
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019-03-14
# 1   Scout  Dalmatian         59         25    2019-05-09

# %% [markdown]
# <a id="Reading-and-writing-CSVs"></a>
# # Reading and writing CSVs
# * CSV = comma-separated values
# * Designed for DataFrame-like data
# * Most database and spreadsheet programs can use them or create them

# %%
file_path ="/Users/chandra/Desktop/FSDS_GenAI_Training/FSDS_Classes/Python_Workspace/ML/RESUME PROJECT -- PRICE PREDICTION/avocado.csv"
avocado = pd.read_csv(file_path)
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %% [markdown]
# ### Read CSV and assign index
# <p>You can assign columns as index using "index_col" attribute.</p>
# <p>Since I want to index Date there is another helpful function called "parse_date" which will parse the date in the rows such that we can perform more complex subsetting(eg monthly, weekly etc).</p>

# %%
# read CSV from using pandas and assigning Date as index of the dataframe
avocado = pd.read_csv(file_path,parse_dates=True)
# print the first few rows of the dataframe

print(avocado.columns)
print(len(avocado.columns))
avocado.head()
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')
# 14
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# ...

# %%
avocado = avocado.reset_index(drop=True)
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %% [markdown]
# To write a CSV file function dataframe.to_csv(FILE_NAME)

# %%
avocado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
avocado.to_csv("test_write.csv")

# %%
avocado.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7           7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8           8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9           9  2015-10-25          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# ...

# %%
avocado.tail(10)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18239           2  2018-03-11          1.56      22128.42  2162.67  3194.25
# 18240           3  2018-03-04          1.54      17393.30  1832.24  1905.57
# 18241           4  2018-02-25          1.57      18421.24  1974.26  2482.65
# 18242           5  2018-02-18          1.56      17597.12  1892.05  1928.36
# 18243           6  2018-02-11          1.57      15986.17  1924.28  1368.32
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# ...

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
print(avocado.shape)
# Out:
# (18249, 14)

# %%
avocado.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
avocado.describe().transform
# Out:
# <bound method DataFrame.transform of          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
avocado.values
# Out:
# array([[0, '2015-12-27', 1.33, ..., 'conventional', 2015, 'Albany'],
#        [1, '2015-12-20', 1.35, ..., 'conventional', 2015, 'Albany'],
#        [2, '2015-12-13', 0.93, ..., 'conventional', 2015, 'Albany'],
#        ...,
#        [9, '2018-01-21', 1.87, ..., 'organic', 2018, 'WestTexNewMexico'],
#        [10, '2018-01-14', 1.93, ..., 'organic', 2018, 'WestTexNewMexico'],
#        [11, '2018-01-07', 1.62, ..., 'organic', 2018, 'WestTexNewMexico']],
#       shape=(18249, 14), dtype=object)

# %%
avocado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
even = pd.Series([2,4,6,8,10])
odd = pd.Series([1,3,5,7,9])
res = pd.concat([even,odd])
res
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 0     1
# 1     3
# 2     5
# 3     7
# 4     9
# dtype: int64

# %%
res.reset_index(drop=True) # notice the index in the previous output, the index number are repeating after merging 2 series even and odd.

# after reset_index(drop=True) the index is reset to the perfect series.
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 5     1
# 6     3
# 7     5
# 8     7
# 9     9
# dtype: int64

# %% [markdown]
# # Sorting

# %%
avocado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
sorted_avocado_df=avocado.sort_values(['AveragePrice', 'year'], ascending=[True,False])
# print(avocado.head(5))
# print(sorted_avocado_df.head(5))

avocado
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
avocado['AveragePrice']
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
avocado['AveragePrice'].mean()
# Out:
# np.float64(1.405978409775878)

# %%
avocado['AveragePrice'].describe()
# Out:
# count    18249.000000
# mean         1.405978
# std          0.402677
# min          0.440000
# 25%          1.100000
# 50%          1.370000
# 75%          1.660000
# max          3.250000
# Name: AveragePrice, dtype: float64

# %%
avocado[["AveragePrice", "Date"]]
# Out:
#        AveragePrice        Date
# 0              1.33  2015-12-27
# 1              1.35  2015-12-20
# 2              0.93  2015-12-13
# 3              1.08  2015-12-06
# 4              1.28  2015-11-29
# ...             ...         ...
# 18244          1.63  2018-02-04
# 18245          1.71  2018-01-28
# 18246          1.87  2018-01-21
# 18247          1.93  2018-01-14
# 18248          1.62  2018-01-07
#
# [18249 rows x 2 columns]

# %%
avocado['AveragePrice']<1
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 18244    False
# 18245    False
# 18246    False
# 18247    False
# 18248    False
# Name: AveragePrice, Length: 18249, dtype: bool

# %%
avocado[avocado['AveragePrice']<1]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume      4046  \
#
# 18103          10  2018-01-14          1.81      21770.02  3285.98   14338.52
# 18104          11  2018-01-07          2.06      16746.82  5150.82    9366.31
#
# ...

# %% [markdown]
# # Detecting missing values .isna()

# %%
avocado.isna().any()
# Out:
# Unnamed: 0      False
# Date            False
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type            False
# year            False
# region          False
# dtype: bool

# %%
avocado.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# # Removing missing values
# * Drop NaN ** .dropna() **
# * Fill NaN with value x ** .fillna(x) **

# %%
avocado.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
# If there are any NaN, we can use any of the two methods

avocado.dropna()

# or 


# find the mean value and fill it for all NaN 
meanval=avocado.AveragePrice.mean()
avocado.fillna(meanval)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# # Add a new column and calculate and insert values

# %%
avocado['AveragePriceFor100'] = avocado['AveragePrice']*100
avocado
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
avocado.drop(['AveragePriceFor100'],axis = 1)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# # the column is deleted but the data is still present
# # useing inplace=True
# # we can force pandas to modify the current DataFrame directly without a reassignment.

# %%
avocado.shape
# Out:
# (18249, 14)

# %%
#inplace=True
avocado.drop(['AveragePriceFor100'], axis=1, inplace=True)

# %%
avocado
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# # Summary statistics
# Some of the functions availabe in pandas are:
#
# # .median() .mode() .min() .max() .var() .std() .sum() .quantile()

# %%
avocado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
def print_statistics_values(attribute):
    print(attribute,"  : Mean = ",avocado[attribute].mean())
    print(attribute,"  : Median = ",avocado[attribute].median())
    print(attribute,"  : Min = ",avocado[attribute].min())
    print(attribute,"  : Max = ",avocado[attribute].max())
    print(attribute,"  : Variance = ",avocado[attribute].var())
    print(attribute,"  : StandartDeviation = ",avocado[attribute].std())
    print(attribute,"  : Sum = ",avocado[attribute].sum())
    print(attribute,"  : Quantile = ",avocado[attribute].quantile())
    print("*"*50)

print_statistics_values('AveragePrice')
print_statistics_values('Total Volume')
# Out:
# AveragePrice   : Mean =  1.405978409775878
# AveragePrice   : Median =  1.37
# AveragePrice   : Min =  0.44
# AveragePrice   : Max =  3.25
# AveragePrice   : Variance =  0.16214840834576077
# AveragePrice   : StandartDeviation =  0.40267655549555004
# AveragePrice   : Sum =  25657.7
# AveragePrice   : Quantile =  1.37
# **************************************************
# Total Volume   : Mean =  850644.013008932
# Total Volume   : Median =  107376.76
# Total Volume   : Min =  84.56
# Total Volume   : Max =  62505646.52
# Total Volume   : Variance =  11926975521801.33
# Total Volume   : StandartDeviation =  3453545.3553994815
# Total Volume   : Sum =  15523402593.4
# Total Volume   : Quantile =  107376.76
# **************************************************

# %% [markdown]
# # .agg() method
#
# Pandas Series.agg() is used to pass a function or list of function to be applied on a series or even each element of series separately.
#
# > Syntax: Series.agg(func, axis=0)
# >
# > Parameters:
# > func: Function, list of function or string of function name to be called on Series.
# > axis:0 or ‘index’ for row wise operation and 1 or ‘columns’ for column wise operation.
# >
# > Return Type: The return type depends on return type of function passed as parameter.

# %%
def pct30(column):     
    #return the 0.3 quartile
    return column.quantile(0.3)

def pct50(column):     
    #return the 0.5 quartile
    return column.quantile(0.5)

avocado[['AveragePrice','Total Bags']].agg([pct30,pct50])
# Out:
#        AveragePrice  Total Bags
# pct30          1.15    7316.634
# pct50          1.37   39743.830

# %% [markdown]
# # Dropping duplicate names .drop_duplicates(lst)
# Delete all the duplicate names from the dataframe

# %%
temp = avocado.drop_duplicates(subset=['year'])
temp
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0              0  2015-12-27          1.33      64236.62   1036.74   54454.85
# 2808           0  2016-12-25          1.52      73341.73   3202.39   58280.33
# 5616           0  2017-12-31          1.47     113514.42   2622.70  101135.53
# 8478           0  2018-03-25          1.57     149396.50  16361.69  109045.03
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0      48.16     8696.87     8603.62       93.25         0.00  conventional
# 2808  426.92    11432.09    11017.32      411.83         2.94  conventional
# 5616   20.25     9735.94     5556.98     4178.96         0.00  conventional
# 8478   65.45    23924.33    19273.80     4270.53       380.00  conventional
#
#       year  region
# 0     2015  Albany
# 2808  2016  Albany
# 5616  2017  Albany
# 8478  2018  Albany

# %%
avocado.shape
# Out:
# (18249, 14)

# %%
avocado['year'].value_counts(sort=True,ascending=False)
# Out:
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: count, dtype: int64

# %% [markdown]
# # Pivot table
# # A pivot table is a table of statistics that summarizes the data of a more extensive table.

# %%
# this is the same table we build in the previous cell but using pivot table
avocado.pivot_table(index=['year','type'], aggfunc=[np.mean,np.median,min,max], values='AveragePrice')
# Out:
# /var/folders/d3/sygkv87x599_23wg1wtqq98c0000gp/T/ipykernel_64014/3354147046.py:2: FutureWarning: The provided callable <function mean at 0x10acb6a20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   avocado.pivot_table(index=['year','type'], aggfunc=[np.mean,np.median,min,max], values='AveragePrice')
# /var/folders/d3/sygkv87x599_23wg1wtqq98c0000gp/T/ipykernel_64014/3354147046.py:2: FutureWarning: The provided callable <function median at 0x10af67ce0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   avocado.pivot_table(index=['year','type'], aggfunc=[np.mean,np.median,min,max], values='AveragePrice')
# ...

# %% [markdown]
# # Explicit indexes

# %%
regionIndex=avocado.set_index(['region'])
regionIndex
# Out:
#                   Unnamed: 0        Date  AveragePrice  Total Volume     4046  \
# region
# Albany                     0  2015-12-27          1.33      64236.62  1036.74
# Albany                     1  2015-12-20          1.35      54876.98   674.28
# Albany                     2  2015-12-13          0.93     118220.22   794.70
# Albany                     3  2015-12-06          1.08      78992.15  1132.00
# Albany                     4  2015-11-29          1.28      51039.60   941.48
# ...                      ...         ...           ...           ...      ...
# WestTexNewMexico           7  2018-02-04          1.63      17074.83  2046.96
# WestTexNewMexico           8  2018-01-28          1.71      13888.04  1191.70
# WestTexNewMexico           9  2018-01-21          1.87      13766.76  1191.92
# WestTexNewMexico          10  2018-01-14          1.93      16205.22  1527.63
# WestTexNewMexico          11  2018-01-07          1.62      17489.58  2894.77
#
# ...

# %%
# Insted of doing this
avocado[avocado["region"].isin(["Albany", "WestTexNewMexico"])]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
regionIndex.loc[['Albany','WestTexNewMexico']]
# Out:
#                   Unnamed: 0        Date  AveragePrice  Total Volume     4046  \
# region
# Albany                     0  2015-12-27          1.33      64236.62  1036.74
# Albany                     1  2015-12-20          1.35      54876.98   674.28
# Albany                     2  2015-12-13          0.93     118220.22   794.70
# Albany                     3  2015-12-06          1.08      78992.15  1132.00
# Albany                     4  2015-11-29          1.28      51039.60   941.48
# ...                      ...         ...           ...           ...      ...
# WestTexNewMexico           7  2018-02-04          1.63      17074.83  2046.96
# WestTexNewMexico           8  2018-01-28          1.71      13888.04  1191.70
# WestTexNewMexico           9  2018-01-21          1.87      13766.76  1191.92
# WestTexNewMexico          10  2018-01-14          1.93      16205.22  1527.63
# WestTexNewMexico          11  2018-01-07          1.62      17489.58  2894.77
#
# ...

# %% [markdown]
# # Visualizing your data

# %%
avocado['AveragePrice'].hist(bins=20)
plt.show()

# %%
# Bar plot
regionFilter =avocado.groupby('region')['AveragePrice'].mean().head(10)
regionFilter
# Out:
# region
# Albany                 1.561036
# Atlanta                1.337959
# BaltimoreWashington    1.534231
# Boise                  1.348136
# Boston                 1.530888
# BuffaloRochester       1.516834
# California             1.395325
# Charlotte              1.606036
# Chicago                1.556775
# CincinnatiDayton       1.209201
# Name: AveragePrice, dtype: float64

# %%
regionFilter.plot(kind='bar',rot=90,title="Average price in 10 regions")
# Out:
# <Axes: title={'center': 'Average price in 10 regions'}, xlabel='region'>

# %%
avocado.plot(kind='scatter',x='AveragePrice', y='Total Volume')
# Out:
# <Axes: xlabel='AveragePrice', ylabel='Total Volume'>

# %%
# Add AveragePrice with AveragePrice 

avocado['AveragePrice'].add(avocado['AveragePrice'])
# Out:
# 0        2.66
# 1        2.70
# 2        1.86
# 3        2.16
# 4        2.56
#          ...
# 18244    3.26
# 18245    3.42
# 18246    3.74
# 18247    3.86
# 18248    3.24
# Name: AveragePrice, Length: 18249, dtype: float64
