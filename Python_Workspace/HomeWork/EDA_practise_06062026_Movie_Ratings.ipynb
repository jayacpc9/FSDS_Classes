# %% [markdown]
# # Exploratory Data Analysis (EDA) : Practise : Movie Rating CVS.

# %%
assets_location ="/Users/chandra/Desktop/FSDS_GenAI_Training/FSDS_Classes/Python_Workspace/assets/"
raw_data_filename ="Movie-Rating.csv"

movie_rating_file = assets_location+raw_data_filename
print("movie_rating_file : ",movie_rating_file)
# Out:
# movie_rating_file :  /Users/chandra/Desktop/FSDS_GenAI_Training/FSDS_Classes/Python_Workspace/assets/Movie-Rating.csv

# %% [markdown]
# # Adding all the related imports

# %%
import pandas as pd
import numpy as np

# %%
movie_rating_df=pd.read_csv(movie_rating_file)

# 1. Stop Pandas from wrapping columns to a new line
# pd.set_option("display.expand_frame_repr", False)

# 2. Optional: Set a high limit on the total width if needed
# pd.set_option("display.width", 1000)

movie_rating_df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movie_rating_df)
# Out:
# 559

# %% [markdown]
# # Check if there are any Null/NaN in the data.

# %%
movie_rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie_rating_df.isna().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
movie_rating_df.isnull().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
movie_rating_df.head(5)
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie_rating_df.tail(5)
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %% [markdown]
# # Listing all columns

# %%
movie_rating_df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %% [markdown]
# # Re-naming the column names : cos the names are are tool large.

# %%
movie_rating_df.columns =['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions', 'Year']
movie_rating_df.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movie_rating_df.head(5)
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movie_rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie_rating_df.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movie_rating_df['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %% [markdown]
# # convert all the datatypes

# %%
movie_rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie_rating_df['Film'] = movie_rating_df['Film'].astype("category")
movie_rating_df['Genre'] = movie_rating_df['Genre'].astype("category")

# movie_rating_df.Film = movie_rating_df.Film.astype('category')
# movie_rating_df.Genre = movie_rating_df.Genre.astype('category')



movie_rating_df['CriticRating'] = movie_rating_df['CriticRating'].astype("int64")
movie_rating_df['AudienceRating']=movie_rating_df['AudienceRating'].astype("int64")
movie_rating_df['BudgetMillions']=movie_rating_df['BudgetMillions'].astype('int64')
movie_rating_df['Year']=movie_rating_df['Year'].astype("int64")

movie_rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
movie_rating_df.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movie_rating_df.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: int64

# %%
all_movie_genres= movie_rating_df.Genre.cat.categories
print("Total numbe of unique Genres = ",len(all_movie_genres))
all_movie_genres
# Out:
# Total numbe of unique Genres =  7
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %% [markdown]
# # Plot the relevent charts

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings
# Out:
# <function warnings.filterwarnings(action, message='', category=<class 'Warning'>, module='', lineno=0, append=False)>

# %%
movie_rating_df.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
sns.jointplot(data=movie_rating_df,x ='CriticRating', y='AudienceRating')

# %%
# Other kind options are as follows : by default it is "Scatter"
# kind: Literal['scatter', 'kde', 'hist', 'hex', 'reg', 'resid'] = "scatter",

sns.jointplot(data=movie_rating_df, x='CriticRating',y='AudienceRating',kind='hex')

# %%
sns.distplot(movie_rating_df.AudienceRating)
# Out:
# /var/folders/d3/sygkv87x599_23wg1wtqq98c0000gp/T/ipykernel_1715/3749887457.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(movie_rating_df.AudienceRating)
# <Axes: xlabel='AudienceRating', ylabel='Density'>

# %%
sns.set_style('darkgrid') # Literal['white', 'dark', 'whitegrid', 'darkgrid', 'ticks'] 
sns.displot(movie_rating_df.AudienceRating)

# %%
sns.histplot(movie_rating_df.AudienceRating,bins=50) # bins =50 : to display more histograms bars,
# Out:
# <Axes: xlabel='AudienceRating', ylabel='Count'>

# %%
sns.histplot(movie_rating_df.CriticRating,bins=50)
# Out:
# <Axes: xlabel='CriticRating', ylabel='Count'>

# %%
plt.hist(movie_rating_df.BudgetMillions)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movie_rating_df[movie_rating_df.Genre == 'Drama'].BudgetMillions, bins= 50)
plt.xlabel("ID")
plt.ylabel("$ in Millions")
plt.legend()
plt.show()
# Out:
# /var/folders/d3/sygkv87x599_23wg1wtqq98c0000gp/T/ipykernel_1715/2094507145.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
all_drama_movies=movie_rating_df[movie_rating_df.Genre == 'Drama']

# total_count=len(all_drama_movies)
# all_drama_movies.head(total_count)

# print(all_drama_movies.head(10))
# print(all_drama_movies.tail(10))

all_drama_movies.BudgetMillions
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64

# %%
sns.lmplot(data=movie_rating_df,x='Year',y='BudgetMillions', hue='Genre', fit_reg=False)

# %%
clean_df = movie_rating_df.astype({"Year": "Int64"})
sns.scatterplot(data=clean_df, x="Year", y="BudgetMillions", hue="Genre")
# Out:
# <Axes: xlabel='Year', ylabel='BudgetMillions'>

# %%
movie_rating_df.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
sns.lmplot(data=movie_rating_df,x='CriticRating',y='AudienceRating', hue='Genre', fit_reg=False)

# %%
movie_rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %% [markdown]
# # list movies by year,genre, most expensive movie,

# %%
movie_rating_df
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
print("Max Year = ",movie_rating_df.Year.max())
print("Min Year = ",movie_rating_df.Year.min())
print("Most Expensive = ", movie_rating_df.BudgetMillions.max())
print("Least Expensive = ", movie_rating_df.BudgetMillions.min())
movie_rating_df.BudgetMillions.max()
# Out:
# Max Year =  2011
# Min Year =  2007
# Most Expensive =  300
# Least Expensive =  0
# 300

# %%
max_budget_movies = movie_rating_df.loc[
    movie_rating_df.BudgetMillions == movie_rating_df.BudgetMillions.max(),
    "Film",
]

max_budget_movies_list =max_budget_movies.to_list()

print("Total number of moview with Max Budget = ",len(max_budget_movies_list))
print(max_budget_movies_list)
print(len(max_budget_movies))
max_budget_movies
# Out:
# Total number of moview with Max Budget =  1
# ["Pirates of the Caribbean: At World's End"]
# 1
# 304    Pirates of the Caribbean: At World's End
# Name: Film, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %% [markdown]
# # high budget movies in a given Genres

# %%
def getMostExpensiveMovie(movie_genre):
    # method accepts a movie genre and returns a df containg the most expensive movie.
    pd.set_option("display.expand_frame_repr", False)
    # get the Genres list
    genres_df = movie_rating_df[movie_rating_df['Genre'] == movie_genre]
    most_expensive_movie =genres_df.loc[genres_df['BudgetMillions'] == genres_df['BudgetMillions'].max()]
    # print(type(most_expensive_movie))
    # print(most_expensive_movie,end='\n')
    return most_expensive_movie


genre = 'Adventure'
most_expensive_movie = getMostExpensiveMovie(movie_genre = genre)
print("most_expensive_movie = ",type(most_expensive_movie))

print(f"Most expensive {genre} Film is = ",most_expensive_movie['Film'].item().strip())
# Out:
# most_expensive_movie =  <class 'pandas.core.frame.DataFrame'>
# Most expensive Adventure Film is =  Harry Potter and the Half-Blood Prince

# %% [markdown]
# # List the most expensive movie from each available category

# %%
# get all the unique Genre from the given csv file.
target_genres = movie_rating_df['Genre'].cat.categories.to_list()
print(target_genres)

# movie dictionary
movie_data={'Film':[],'Genre':[],'CriticRating':[],'AudienceRating':[],'BudgetMillions':[],'Year':[]}
#movie list to hold all the most expensive movies dictionary.
movie_list=[]

# for loop to request all the most expensive movies by the category
for genre in target_genres:
    most_expensive_movie = getMostExpensiveMovie(genre)    
    records_hash = most_expensive_movie.to_dict(orient="records")
    movie_list.append(records_hash[0]) # adding the dictionary to the list
    # print("records_hash : ",records_hash[0])

# filter to sort all final result by one of the available categories
sort_by='BudgetMillions'
movie_list.sort(key=lambda movie: movie[sort_by])


# iterate the list of dictionary items.
for movie in movie_list:
    for key,val in movie.items():
        print(f"{key} : {val}")
    print()

# print the details in a neat format
print(f"{'Year':<6} |{'GENRE':<12} | {'BUDGET':<6} | {'FILM'}")
print("-" * 60)
for movie in movie_list:
    print(f"{movie['Year']:<6} |{movie['Genre']:<12} | ${movie['BudgetMillions']:<5}M | {movie['Film'].strip()}")
# Out:
# ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']
# Film : Dream House
# Genre : Horror
# CriticRating : 7
# AudienceRating : 38
# BudgetMillions : 50
# Year : 2011
#
# Film : Twilight: Breaking Dawn
# Genre : Romance
# CriticRating : 26
# AudienceRating : 68
# BudgetMillions : 110
# Year : 2011
#
# Film : The Wolfman
# Genre : Drama
# CriticRating : 33
# AudienceRating : 38
# BudgetMillions : 150
# Year : 2010
#
# Film : Evan Almighty
# Genre : Comedy
# CriticRating : 23
# AudienceRating : 56
# BudgetMillions : 175
# Year : 2007
#
# Film : The Dark Knight
# Genre : Thriller
# CriticRating : 94
# AudienceRating : 96
# BudgetMillions : 185
# Year : 2008
#
# Film : Harry Potter and the Half-Blood Prince
# Genre : Adventure
# CriticRating : 83
# AudienceRating : 75
# BudgetMillions : 250
# Year : 2009
#
# Film : Pirates of the Caribbean: At World's End
# Genre : Action
# CriticRating : 45
# AudienceRating : 74
# BudgetMillions : 300
# Year : 2007
#
# ...

# %% [markdown]
# # filter by multiple genres

# %%
target_genres = ["Action", "Adventure",'Comedy']

genre_group_df = movie_rating_df[movie_rating_df["Genre"].isin(target_genres)]
print("genre_group_df == \n",genre_group_df)
most_expensive_genre=genre_group_df.loc[genre_group_df['BudgetMillions'] == genre_group_df['BudgetMillions'].max(),'Film']
# max_group_movies =.  genre_group_df.loc[genre_group_df["BudgetMillions"] == genre_group_df["BudgetMillions"].max(),"Film",].tolist()
most_expensive_genre.to_list()
# Out:
# genre_group_df ==
#                                     Film      Genre  CriticRating  AudienceRating  BudgetMillions  Year
# 0                 (500) Days of Summer      Comedy            87              81               8  2009
# 1                           10,000 B.C.  Adventure             9              44             105  2008
# 2                            12 Rounds      Action            30              52              20  2009
# 3                             127 Hours  Adventure            93              84              18  2010
# 4                             17 Again      Comedy            55              70              20  2009
# ..                                  ...        ...           ...             ...             ...   ...
# 553  You Will Meet a Tall Dark Stranger     Comedy            43              35              22  2010
# 554                       Your Highness     Comedy            26              36              50  2011
# ...
